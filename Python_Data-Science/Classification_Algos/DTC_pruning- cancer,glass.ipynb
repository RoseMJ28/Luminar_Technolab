# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/cancer_data.csv')
df
# Out:
#      mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      diagnosis
# 0            0
# 1            0
# 2            0
# ...

# %%
df.dtypes
# Out:
# mean_radius        float64
# mean_texture       float64
# mean_perimeter     float64
# mean_area          float64
# mean_smoothness    float64
# diagnosis            int64
# dtype: object

# %%
df.isna().sum()
# Out:
# mean_radius        0
# mean_texture       0
# mean_perimeter     0
# mean_area          0
# mean_smoothness    0
# diagnosis          0
# dtype: int64

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=1)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
#
# Out:
# ((398, 5), (398,), (171, 5), (171,))

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='entropy',random_state=1,max_depth=6)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=1)

# %%
y_pred=dt.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        63
#            1       0.88      0.94      0.91       108
#
#     accuracy                           0.88       171
#    macro avg       0.88      0.86      0.86       171
# weighted avg       0.88      0.88      0.88       171

# %%
dt.score(X_test,y_test)  #can be used before y_pred prediction score() directly predict and compare with y_test
# Out:
# 0.8771929824561403

# %%
dt.score(X_train,y_train)
# Out:
# 0.9798994974874372

# %%
df1=pd.read_csv('/content/drive/MyDrive/Datasets/glass.csv')
df1
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df1.isna().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df1.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
X=df1.iloc[:,:-1]
y=df1.iloc[:,-1]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(criterion='gini',random_state=1,max_depth=9)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=9, random_state=1)

# %%
y_pred1=dt.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.72      0.75        25
#            2       0.62      0.71      0.67        21
#            3       0.33      0.14      0.20         7
#            5       0.33      0.50      0.40         2
#            6       0.33      1.00      0.50         1
#            7       0.89      0.89      0.89         9
#
#     accuracy                           0.68        65
#    macro avg       0.55      0.66      0.57        65
# weighted avg       0.68      0.68      0.67        65
