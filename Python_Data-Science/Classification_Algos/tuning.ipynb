# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

scaler=MinMaxScaler()
X=scaler.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

model=RandomForestClassifier()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.8311688311688312

# %% [markdown]
# # with hyper parameters

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
params={'n_estimators':[100,200,250,300],'criterion':['gini','entropy','log_loss'],'max_depth':[3,4,6,8]}
clf=RandomizedSearchCV(model,params,cv=10,scoring='accuracy')
clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-78b3551f144b> in <cell line: 4>()
#       2 params={'n_estimators':[100,200,250,300],'criterion':['gini','entropy','log_loss'],'max_depth':[3,4,6,8]}
#       3 clf=RandomizedSearchCV(model,params,cv=10,scoring='accuracy')
# ----> 4 clf.fit(X_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

scaler=MinMaxScaler()
X=scaler.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

model=SVC()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

accuracy_score(y_test,y_pred)
# Out:
# 0.7922077922077922

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
params={'degree':[3,4,5,7],'kernel':['rbf','linear','poly'],'gamma':['scale','auto']}
clf=RandomizedSearchCV(model,params,cv=10,scoring='accuracy')
clf.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# RandomizedSearchCV(cv=10, estimator=SVC(),
#                    param_distributions={'degree': [3, 4, 5, 7],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['rbf', 'linear', 'poly']},
#                    scoring='accuracy')

# %%
print(clf.best_params_)
# Out:
# {'kernel': 'linear', 'gamma': 'auto', 'degree': 7}

# %%
clf=svc(kernel='linear',gamma='auto',degree=7)
knn1.fit(X_train,y_train)
y_pred1=knn1.predict(X_test)
print(accuracy_score(y_test,y_pred1))
