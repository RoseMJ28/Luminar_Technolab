# %%
import pandas as pd

# %%
s=pd.Series([1,2,5,9])
s
# Out:
# 0    1
# 1    2
# 2    5
# 3    9
# dtype: int64

# %%
s.ndim
# Out:
# 1

# %%
s.shape
# Out:
# (4,)

# %%
df=pd.DataFrame([1,2,5,9])
df
# Out:
#    0
# 0  1
# 1  2
# 2  5
# 3  9

# %%
df.shape
# Out:
# (4, 1)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # **Series**

# %%
S=pd.Series([5,6,8,0,2,5,6],index=['a','b','c','d','e','f','g'],dtype=float)
S
# Out:
# a    5.0
# b    6.0
# c    8.0
# d    0.0
# e    2.0
# f    5.0
# g    6.0
# dtype: float64

# %%
S[1]
# Out:
# <ipython-input-28-4e06216c2585>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   S[1]
# 6.0

# %%
S.iloc[1]
# Out:
# 6.0

# %%
S['b']
# Out:
# 6.0

# %%
S[1:5]
# Out:
# b    6.0
# c    8.0
# d    0.0
# e    2.0
# dtype: float64

# %%
S.iloc[1:5]
# Out:
# b    6.0
# c    8.0
# d    0.0
# e    2.0
# dtype: float64

# %%
S['b':'e']
# Out:
# b    6.0
# c    8.0
# d    0.0
# e    2.0
# dtype: float64

# %% [markdown]
# # **DataFrame**

# %%
#using nested list
lst=[[12,'kaveri','BCA'],[13,'Abhirami','BBA'],[16,'Adhil','BCA'],[21,'Appu','BBA']]
df=pd.DataFrame(lst,columns=['RollNo','Name','Batch'])
df
# Out:
#    RollNo      Name Batch
# 0      12    kaveri   BCA
# 1      13  Abhirami   BBA
# 2      16     Adhil   BCA
# 3      21      Appu   BBA

# %%
#using list of dictionaries
lst1=[{'RollNo':12,'Name':'Kaveri','Batch':'BCA'},{'RollNo':13,'Name':'Abhirami','Batch':'BBA'},{'RollNo':16,'Name':'Adhil','Batch':'BCA'},{'RollNo':21,'Name':'Appu','Batch':'BBA'}]
df1=pd.DataFrame(lst1)
df1
# Out:
#    RollNo      Name Batch
# 0      12    Kaveri   BCA
# 1      13  Abhirami   BBA
# 2      16     Adhil   BCA
# 3      21      Appu   BBA

# %%
#using dictionary of list
dic={'RollNo':[12,13,16,21],'Name':['Kaveri','Abhirami','Adhil','Appu'],'Batch':['BCA','BBA','BCA','BBA']}
df2=pd.DataFrame(dic)
df2
# Out:
#    RollNo      Name Batch
# 0      12    Kaveri   BCA
# 1      13  Abhirami   BBA
# 2      16     Adhil   BCA
# 3      21      Appu   BBA

# %%
dic={'Empid':[101,102,103,104,105,101],'Empname':['Sam','Trisha','Anu','Manu','Dev','Sam'],'Designation':['Manager','Developer','Developer','Manager','Developer','Manager'],'Salary':[10000,13000,14000,16000,20000,10000],'Location':['Mumbai','Delhi','Goa','Chennai','Kerala','Mumbai']}
df3=pd.DataFrame(dic)
df3
# Out:
#    Empid Empname Designation  Salary Location
# 0    101     Sam     Manager   10000   Mumbai
# 1    102  Trisha   Developer   13000    Delhi
# 2    103     Anu   Developer   14000      Goa
# 3    104    Manu     Manager   16000  Chennai
# 4    105     Dev   Developer   20000   Kerala
# 5    101     Sam     Manager   10000   Mumbai

# %%
#adding new column to df3
df3['Gender']=['M','F','F','M','M']
df3
# Out:
#    Empid Empname Designation  Salary Location Gender
# 0    101     Sam     Manager   10000   Mumbai      M
# 1    102  Trisha   Developer   13000    Delhi      F
# 2    103     Anu   Developer   14000      Goa      F
# 3    104    Manu     Manager   16000  Chennai      M
# 4    105     Dev   Developer   20000   Kerala      M

# %%
lst=[{'Empid':101,'Empname':'Sam','Designation':'Manager','Salary':10000,'Location':'Mumbai'},{'Empid':102,'Empname':'Trisha','Designation':'Developer','Salary':13000,'Location':'Delhi'},{'Empid':103,'Empname':'Anu','Designation':'Developer','Salary':14000,'Location':'Goa'},{'Empid':104,'Empname':'Manu','Designation':'Manager','Salary':16000,'Location':'Chennai'},{'Empid':105,'Empname':'Dev','Designation':'Developer','Salary':20000,'Location':'Kerala'}]
df4=pd.DataFrame(lst)
df4
# Out:
#    Empid Empname Designation  Salary Location
# 0    101     Sam     Manager   10000   Mumbai
# 1    102  Trisha   Developer   13000    Delhi
# 2    103     Anu   Developer   14000      Goa
# 3    104    Manu     Manager   16000  Chennai
# 4    105     Dev   Developer   20000   Kerala

# %%
lst2=[[101,'Sam','Manager',10000,'Mumbai'],[102,'Trisha','Developer',13000,'Delhi'],[103,'Anu','Developer',14000,'Goa'],[104,'Manu','Manager',16000,'Chennai'],[105,'Dev','Developer',20000,'Kerala']]
df5=pd.DataFrame(lst2,columns=['Empid','Empname','Designation','Salary','Location'])
df5
# Out:
#    Empid Empname Designation  Salary Location
# 0    101     Sam     Manager   10000   Mumbai
# 1    102  Trisha   Developer   13000    Delhi
# 2    103     Anu   Developer   14000      Goa
# 3    104    Manu     Manager   16000  Chennai
# 4    105     Dev   Developer   20000   Kerala

# %%
#to show only one column from dataframe
df3['Empname']  #--> return 1D dataframe
df3[['Empname']]
# Out:
#   Empname
# 0     Sam
# 1  Trisha
# 2     Anu
# 3    Manu
# 4     Dev

# %%
#to show more than one column
df5[['Empname','Salary']]
# Out:
#   Empname  Salary
# 0     Sam   10000
# 1  Trisha   13000
# 2     Anu   14000
# 3    Manu   16000
# 4     Dev   20000

# %%
#retrieve name and designation of 1 to 3 employees
df5.iloc[1:4,1:3]
# Out:
#   Empname Designation
# 1  Trisha   Developer
# 2     Anu   Developer
# 3    Manu     Manager

# %% [markdown]
# # OR

# %%
df5.iloc[1:4][['Empname','Designation']]
# Out:
#   Empname Designation
# 1  Trisha   Developer
# 2     Anu   Developer
# 3    Manu     Manager

# %%
# retrieving empname and salary from emplyee 1 to 3
df5.iloc[1:4,[1,3]]
# Out:
#   Empname  Salary
# 1  Trisha   13000
# 2     Anu   14000
# 3    Manu   16000

# %%
df=pd.read_csv('/content/customer (1)',names=['ID','Fname','Lname','Age','Profession','Country'])
df
# Out:
#           ID     Fname    Lname  Age                  Profession  Country
# 0    4000001  Kristina    Chung   55                       Pilot    india
# 1    4000002     Paige     Chen   74                     Teacher       uk
# 2    4000003    Sherri   Melton   34                 Firefighter       us
# 3    4000004  Gretchen     Hill   66  Computer hardware engineer    china
# 4    4000005     Karen  Puckett   74                      Lawyer   africa
# ..       ...       ...      ...  ...                         ...      ...
# 458  4000459  Gretchen  Francis   60                  Politician  ireland
# 459  4000460    Cheryl     Horn   40                Veterinarian  ireland
# 460  4000461    Audrey  Forrest   50                   Architect  ireland
# 461  4000462      Alan    Levin   43                Statistician  ireland
# 462  4000463     Wayne   Weiner   70                       Actor  ireland
#
# [463 rows x 6 columns]

# %% [markdown]
# **CSV Functions**

# %%
df.head()   #returns 1st 5 observations
# Out:
#         ID     Fname    Lname  Age                  Profession Country
# 0  4000001  Kristina    Chung   55                       Pilot   india
# 1  4000002     Paige     Chen   74                     Teacher      uk
# 2  4000003    Sherri   Melton   34                 Firefighter      us
# 3  4000004  Gretchen     Hill   66  Computer hardware engineer   china
# 4  4000005     Karen  Puckett   74                      Lawyer  africa

# %%
df.tail()  # returns last 5 observations
# Out:
#           ID     Fname    Lname  Age    Profession  Country
# 458  4000459  Gretchen  Francis   60    Politician  ireland
# 459  4000460    Cheryl     Horn   40  Veterinarian  ireland
# 460  4000461    Audrey  Forrest   50     Architect  ireland
# 461  4000462      Alan    Levin   43  Statistician  ireland
# 462  4000463     Wayne   Weiner   70         Actor  ireland

# %%
df.head(20)  #returns first 20 observations
# Out:
#          ID     Fname       Lname  Age                   Profession    Country
# 0   4000001  Kristina       Chung   55                        Pilot      india
# 1   4000002     Paige        Chen   74                      Teacher         uk
# 2   4000003    Sherri      Melton   34                  Firefighter         us
# 3   4000004  Gretchen        Hill   66   Computer hardware engineer      china
# 4   4000005     Karen     Puckett   74                       Lawyer     africa
# 5   4000006   Patrick        Song   42                 Veterinarian  australia
# 6   4000007     Elsie    Hamilton   43                        Pilot    ireland
# 7   4000008     Hazel      Bender   63                    Carpenter      india
# 8   4000009   Malcolm      Wagner   39                       Artist      india
# 9   4000010   Dolores  McLaughlin   60                       Writer      india
# 10  4000011   Francis    McNamara   47                    Therapist      india
# ...

# %%
df.tail(12)  #returns last 12 observations
# Out:
#           ID     Fname    Lname  Age                  Profession  Country
# 451  4000452    Marsha     Gold   36                     Athlete  ireland
# 452  4000453       Kim  Hensley   64                Photographer  ireland
# 453  4000454  Virginia   Turner   22  Computer hardware engineer  ireland
# 454  4000455   Deborah   French   56                  Accountant  ireland
# 455  4000456     Peter   Hughes   38  Computer software engineer  ireland
# 456  4000457   Bernard     Pate   34                      Doctor  ireland
# 457  4000458    Harold  Burnett   40                    Musician  ireland
# 458  4000459  Gretchen  Francis   60                  Politician  ireland
# 459  4000460    Cheryl     Horn   40                Veterinarian  ireland
# 460  4000461    Audrey  Forrest   50                   Architect  ireland
# 461  4000462      Alan    Levin   43                Statistician  ireland
# 462  4000463     Wayne   Weiner   70                       Actor  ireland

# %%
df.info()  #returns information about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          463 non-null    int64
#  1   Fname       463 non-null    object
#  2   Lname       463 non-null    object
#  3   Age         463 non-null    int64
#  4   Profession  463 non-null    object
#  5   Country     463 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 21.8+ KB

# %%
df5.describe()  #returns statistical information about dataframe
# Out:
#             Empid        Salary
# count    5.000000      5.000000
# mean   103.000000  14600.000000
# std      1.581139   3714.835124
# min    101.000000  10000.000000
# 25%    102.000000  13000.000000
# 50%    103.000000  14000.000000
# 75%    104.000000  16000.000000
# max    105.000000  20000.000000

# %%
df5.describe(include='object')  #returns string information about dataframe
# Out:
#        Empname Designation Location
# count        5           5        5
# unique       5           2        5
# top        Sam   Developer   Mumbai
# freq         1           3        1

# %%
df5.describe(include='all')  #returns both string and numerical info about dataframe
# Out:
#              Empid Empname Designation        Salary Location
# count     5.000000       5           5      5.000000        5
# unique         NaN       5           2           NaN        5
# top            NaN     Sam   Developer           NaN   Mumbai
# freq           NaN       1           3           NaN        1
# mean    103.000000     NaN         NaN  14600.000000      NaN
# std       1.581139     NaN         NaN   3714.835124      NaN
# min     101.000000     NaN         NaN  10000.000000      NaN
# 25%     102.000000     NaN         NaN  13000.000000      NaN
# 50%     103.000000     NaN         NaN  14000.000000      NaN
# 75%     104.000000     NaN         NaN  16000.000000      NaN
# max     105.000000     NaN         NaN  20000.000000      NaN

# %%
# display 50 to 100 observation of customer
df.iloc[50:101]
# OR
df.iloc[50:101,:]
# Out:
#           ID      Fname        Lname  Age                       Profession  \
# 50   4000051  Frederick        Baker   52                           Writer
# 51   4000052    Shirley      Merritt   21                         Reporter
# 52   4000053      Jason        Cross   56                   Civil engineer
# 53   4000054     Judith       Cooper   22                        Economist
# 54   4000055   Gretchen       Holmes   39                 Childcare worker
# 55   4000056        Don       Sharpe   53                    Social worker
# 56   4000057     Glenda       Morgan   37                Real estate agent
# 57   4000058      Scott        Hoyle   40                           Doctor
# 58   4000059        Pat        Allen   45                        Secretary
# 59   4000060   Michelle         Rich   44                           Artist
# 60   4000061    Jessica         Rich   37                            Actor
# ...

# %%
# display fname and profession of all customers
df[['Fname','Profession']]
# Out:
#         Fname                  Profession
# 0    Kristina                       Pilot
# 1       Paige                     Teacher
# 2      Sherri                 Firefighter
# 3    Gretchen  Computer hardware engineer
# 4       Karen                      Lawyer
# ..        ...                         ...
# 458  Gretchen                  Politician
# 459    Cheryl                Veterinarian
# 460    Audrey                   Architect
# 461      Alan                Statistician
# 462     Wayne                       Actor
#
# [463 rows x 2 columns]

# %%
# display fname,lname and profession of customer with indices 200-250
df.iloc[200:251][['Fname','Lname','Profession']]
# Out:
#           Fname      Lname                       Profession
# 200     Timothy    McNeill                        Librarian
# 201         Ted  Weinstein        Human resources assistant
# 202      Sandra  Middleton                        Librarian
# 203      Billie       Moss                     Photographer
# 204   Katharine      Lucas                      Electrician
# 205      Lester       Rich        Human resources assistant
# 206      Johnny    Carlton                        Librarian
# 207      Ashley      Brady                Financial analyst
# 208      Lauren    Schultz                      Electrician
# 209     Carolyn    Nichols  Agricultural and food scientist
# 210       Louis     Harvey                Financial analyst
# 211    Charlene  Stevenson                        Carpenter
# 212      Ashley    Houston                            Judge
# 213      Sheryl       Dunn                   Civil engineer
# 214         Ben       West                      Electrician
# ...

# %%
# extracting specific details from dataset
#  df.loc[condition]
df.loc[df['Country']=="india"]
# Out:
#          ID     Fname       Lname  Age                   Profession Country
# 0   4000001  Kristina       Chung   55                        Pilot   india
# 7   4000008     Hazel      Bender   63                    Carpenter   india
# 8   4000009   Malcolm      Wagner   39                       Artist   india
# 9   4000010   Dolores  McLaughlin   60                       Writer   india
# 10  4000011   Francis    McNamara   47                    Therapist   india
# 11  4000012     Sandy      Raynor   26                       Writer   india
# 12  4000013    Marion        Moon   41                    Carpenter   india
# 13  4000014      Beth     Woodard   65                     Musician   india
# 14  4000015     Julia       Desai   49                     Musician   india
# 15  4000016    Jerome     Wallace   52                   Pharmacist   india
# 16  4000017      Neal    Lawrence   72  Computer support specialist   india
# ...

# %%
# display details of customers where prof =doctor
df.loc[df['Profession']=='Doctor']
# Out:
#           ID      Fname     Lname  Age Profession    Country
# 21   4000022       Eric    Steele   66     Doctor      india
# 42   4000043       Paul     Woods   63     Doctor         uk
# 47   4000048    Darlene    Barton   54     Doctor         uk
# 57   4000058      Scott     Hoyle   40     Doctor         uk
# 76   4000077   Samantha    Hardin   27     Doctor         us
# 217  4000218      Brett    Snyder   22     Doctor     africa
# 231  4000232     Marvin   Parrott   67     Doctor     africa
# 252  4000253     Wesley     Moser   64     Doctor     africa
# 353  4000354     Harold        Li   49     Doctor  australia
# 363  4000364  Christina    Harris   39     Doctor  australia
# 387  4000388       Jean   Garrett   73     Doctor    ireland
# 421  4000422      Tommy  Burnette   72     Doctor    ireland
# 456  4000457    Bernard      Pate   34     Doctor    ireland

# %%
# count of specific condition details
len(df.loc[df['Profession']=='Doctor'])
# Out:
# 13

# %%
# cust details where doctor and africa
# df.loc[(cond 1)&(cond 2)]
df.loc[(df['Profession']=='Doctor')&(df['Country']=='africa')]
# Out:
#           ID   Fname    Lname  Age Profession Country
# 217  4000218   Brett   Snyder   22     Doctor  africa
# 231  4000232  Marvin  Parrott   67     Doctor  africa
# 252  4000253  Wesley    Moser   64     Doctor  africa

# %%
# display fname and age of all childcare workers
df.loc[df['Profession']=='Childcare worker'][['Fname','Age']]
# Out:
#         Fname  Age
# 17       Jean   45
# 33     Jerome   38
# 36      Elsie   27
# 54   Gretchen   39
# 66       Luis   69
# 90      Kelly   69
# 123  Benjamin   64
# 132  Samantha   72
# 191    Alison   26
# 192      Eric   61
# 221      Glen   63
# 245    Arthur   58
# 260    Miriam   27
# 292       Kay   44
# 333     Keith   65
# 355       Kay   56
# 443    Thomas   51

# %%
# find count of musicians
len(df.loc[df['Profession']=='Musician'])
# Out:
# 15

# %%
# display details where age >60 and from india
df.loc[(df['Age']>60)&(df['Country']=='india')]
# Out:
#          ID     Fname      Lname  Age                   Profession Country
# 7   4000008     Hazel     Bender   63                    Carpenter   india
# 13  4000014      Beth    Woodard   65                     Musician   india
# 16  4000017      Neal   Lawrence   72  Computer support specialist   india
# 18  4000019  Kristine  Dougherty   63            Financial analyst   india
# 19  4000020   Crystal     Powers   67       Engineering technician   india
# 21  4000022      Eric     Steele   66                       Doctor   india
# 26  4000027    Marcia      Walsh   64                   Accountant   india

# %%
# display fname,age and country 25<age>35
df.loc[(df['Age']>25)&(df['Age']<35)][['Fname','Age','Country']]
# Out:
#          Fname  Age  Country
# 2       Sherri   34       us
# 11       Sandy   26    india
# 23    Franklin   28    india
# 25      Marian   27    india
# 36       Elsie   27       uk
# ..         ...  ...      ...
# 440      Alice   32  ireland
# 441  Elisabeth   34  ireland
# 447        Guy   34  ireland
# 448      Terry   30  ireland
# 456    Bernard   34  ireland
#
# [74 rows x 3 columns]

# %%
# count of dancers from india
len(df.loc[(df['Profession']=='Dancer')&(df['Country']=='india')])
# Out:
# 1

# %% [markdown]
# # Sorting

# %%
# df.sort_values(by='colname')

# %%
# sort according to age
df_age=df.sort_values(by='Age')
df_age
# Out:
#           ID     Fname      Lname  Age           Profession    Country
# 175  4000176   Kristin  Alexander   21                Coach      china
# 289  4000290      Gail  Whitehead   21                Nurse  australia
# 348  4000349   Russell     Dalton   21       Civil engineer  australia
# 291  4000292     Donna       Rice   21        Social worker  australia
# 51   4000052   Shirley    Merritt   21             Reporter         uk
# ..       ...       ...        ...  ...                  ...        ...
# 258  4000259  Margaret    Burgess   74        Social worker     africa
# 241  4000242      Edna      Hoyle   74  Electrical engineer     africa
# 306  4000307     Karen   Clements   74               Farmer  australia
# 324  4000325      Ruth     Harmon   75               Artist  australia
# 88   4000089    Sherri     Sutton   75        Social worker         us
#
# [463 rows x 6 columns]

# %%
df_age.to_csv('Customer_age.csv')   #to save the file as csv

# %%
df.sort_values(by='Age',ascending=False)  #descending order
# Out:
#           ID     Fname      Lname  Age     Profession    Country
# 88   4000089    Sherri     Sutton   75  Social worker         us
# 324  4000325      Ruth     Harmon   75         Artist  australia
# 391  4000392      Emma      Olson   74          Pilot    ireland
# 258  4000259  Margaret    Burgess   74  Social worker     africa
# 306  4000307     Karen   Clements   74         Farmer  australia
# ..       ...       ...        ...  ...            ...        ...
# 175  4000176   Kristin  Alexander   21          Coach      china
# 289  4000290      Gail  Whitehead   21          Nurse  australia
# 450  4000451   Russell       Hess   21      Architect    ireland
# 51   4000052   Shirley    Merritt   21       Reporter         uk
# 291  4000292     Donna       Rice   21  Social worker  australia
#
# [463 rows x 6 columns]

# %%
# to create a copy of dataframe
df_copy=df.copy()

# %%
df_copy.sort_values(by='Age',ascending=False,inplace=True)
df_copy
# Out:
#           ID     Fname      Lname  Age     Profession    Country
# 88   4000089    Sherri     Sutton   75  Social worker         us
# 324  4000325      Ruth     Harmon   75         Artist  australia
# 391  4000392      Emma      Olson   74          Pilot    ireland
# 258  4000259  Margaret    Burgess   74  Social worker     africa
# 306  4000307     Karen   Clements   74         Farmer  australia
# ..       ...       ...        ...  ...            ...        ...
# 175  4000176   Kristin  Alexander   21          Coach      china
# 289  4000290      Gail  Whitehead   21          Nurse  australia
# 450  4000451   Russell       Hess   21      Architect    ireland
# 51   4000052   Shirley    Merritt   21       Reporter         uk
# 291  4000292     Donna       Rice   21  Social worker  australia
#
# [463 rows x 6 columns]

# %%
# reset index
df_copy.reset_index(drop=True,inplace=True)   #remove previous unordered index
df_copy
# Out:
#           ID     Fname      Lname  Age     Profession    Country
# 0    4000089    Sherri     Sutton   75  Social worker         us
# 1    4000325      Ruth     Harmon   75         Artist  australia
# 2    4000392      Emma      Olson   74          Pilot    ireland
# 3    4000259  Margaret    Burgess   74  Social worker     africa
# 4    4000307     Karen   Clements   74         Farmer  australia
# ..       ...       ...        ...  ...            ...        ...
# 458  4000176   Kristin  Alexander   21          Coach      china
# 459  4000290      Gail  Whitehead   21          Nurse  australia
# 460  4000451   Russell       Hess   21      Architect    ireland
# 461  4000052   Shirley    Merritt   21       Reporter         uk
# 462  4000292     Donna       Rice   21  Social worker  australia
#
# [463 rows x 6 columns]

# %%
# display details of highest ages 3 cust
df.sort_values(by='Age',ascending=False).head(3)
# Out:
#           ID   Fname   Lname  Age     Profession    Country
# 88   4000089  Sherri  Sutton   75  Social worker         us
# 324  4000325    Ruth  Harmon   75         Artist  australia
# 391  4000392    Emma   Olson   74          Pilot    ireland

# %%
# display details of highest aged musician
df.loc[(df['Profession']=='Musician')].sort_values(by='Age',ascending=False).head(1)
# Out:
#           ID  Fname     Lname  Age Profession    Country
# 359  4000360  Alvin  McDonald   73   Musician  australia

# %%
# lowest aged doctor
df.loc[(df['Profession']=='Doctor')].sort_values(by='Age').head(1)
# Out:
#           ID  Fname   Lname  Age Profession Country
# 217  4000218  Brett  Snyder   22     Doctor  africa

# %%
# display the number of persons from india
len(df.loc[df['Country']=='india'])
# Out:
# 21

# %%
# display the deatils of persons from us
df.loc[df['Country']=='us']
# Out:
#           ID   Fname    Lname  Age                   Profession Country
# 2    4000003  Sherri   Melton   34                  Firefighter      us
# 63   4000064  Calvin     Diaz   65                      Athlete      us
# 64   4000065  Eugene   Graham   52               Police officer      us
# 65   4000066  Vickie  Watkins   55  Computer support specialist      us
# 66   4000067    Luis   Hinton   69             Childcare worker      us
# ..       ...     ...      ...  ...                          ...     ...
# 135  4000136  Dianne   Norman   68                 Veterinarian      us
# 136  4000137  Rhonda     Chan   34                   Pharmacist      us
# 137  4000138  Tamara     Hunt   25                 Psychologist      us
# 138  4000139    Mary     Byrd   34      Environmental scientist      us
# 139  4000140  Sidney     Lane   54                 Statistician      us
#
# [78 rows x 6 columns]

# %%
# display fname,lname,age of all persons from china in ascending order of age
df.loc[df['Country']=='china'][['Fname','Lname','Age']].sort_values(by='Age')
# Out:
#          Fname      Lname  Age
# 175    Kristin  Alexander   21
# 151    Vincent    Goldman   22
# 144      Roger      Hanna   23
# 153     Milton      Starr   23
# 191     Alison  MacDonald   26
# 142      Katie        May   28
# 158       Glen     Abbott   29
# 170    Stephen      Finch   30
# 165     Martha     Monroe   31
# 149     Martin       Vick   31
# 160      Alice       Hall   33
# 174        Ben   Whitaker   35
# 179      Louis    Rollins   35
# 161      Bruce    Farrell   35
# 182  Constance      Black   36
# 173      Doris     Kinney   36
# 145    Natalie   Locklear   37
# 189        Kim   Matthews   38
# 178       Mark     Becker   39
# 168     Robert       Reid   39
# 180      Janet       Love   39
# 152       Beth    McKenna   40
# 187     Jerome      Joyce   40
# 148       Neal     Glover   40
# 181        Leo     Adkins   42
# 166       Lynn  Robertson   45
# 167       Jose      Sykes   47
# 186      Hazel      Lloyd   48
# 176       Ryan     Conner   51
# ...

# %%
# display max ages ireland person
df.loc[df['Country']=='ireland'].sort_values(by='Age').tail(1)
# Out:
#           ID Fname  Lname  Age Profession  Country
# 391  4000392  Emma  Olson   74      Pilot  ireland

# %%
# display the prof of min aged person from india
df.loc[df['Country']=='india'].sort_values(by='Age').head(1)['Profession']
# Out:
# 11    Writer
# Name: Profession, dtype: object

# %%
# display details where age greater than 70
df.loc[df['Age']>70]
# Out:
#           ID     Fname       Lname  Age                     Profession  \
# 1    4000002     Paige        Chen   74                        Teacher
# 4    4000005     Karen     Puckett   74                         Lawyer
# 16   4000017      Neal    Lawrence   72    Computer support specialist
# 37   4000038      Beth      Walton   73                    Firefighter
# 86   4000087     Steve      Graves   73                          Nurse
# 88   4000089    Sherri      Sutton   75                  Social worker
# 99   4000100    Ronnie       Cowan   71                   Photographer
# 101  4000102      Gene     Bowling   73  Recreation and fitness worker
# 112  4000113     Alice   Blanchard   73                      Economist
# 113  4000114      Joan  McAllister   73         Engineering technician
# 131  4000132   Jessica      Hester   72                 Civil engineer
# 132  4000133  Samantha       Floyd   72               Childcare worker
# ...

# %%
df.isna()  # to find missing values
# Out:
#         ID  Fname  Lname    Age  Profession  Country
# 0    False  False  False  False       False    False
# 1    False  False  False  False       False    False
# 2    False  False  False  False       False    False
# 3    False  False  False  False       False    False
# 4    False  False  False  False       False    False
# ..     ...    ...    ...    ...         ...      ...
# 458  False  False  False  False       False    False
# 459  False  False  False  False       False    False
# 460  False  False  False  False       False    False
# 461  False  False  False  False       False    False
# 462  False  False  False  False       False    False
#
# [463 rows x 6 columns]

# %%
df.isna().sum()  # to find count of missing values
# Out:
# ID            0
# Fname         0
# Lname         0
# Age           0
# Profession    0
# Country       0
# dtype: int64

# %%
df.isnull()  # to find null values
# Out:
#         ID  Fname  Lname    Age  Profession  Country
# 0    False  False  False  False       False    False
# 1    False  False  False  False       False    False
# 2    False  False  False  False       False    False
# 3    False  False  False  False       False    False
# 4    False  False  False  False       False    False
# ..     ...    ...    ...    ...         ...      ...
# 458  False  False  False  False       False    False
# 459  False  False  False  False       False    False
# 460  False  False  False  False       False    False
# 461  False  False  False  False       False    False
# 462  False  False  False  False       False    False
#
# [463 rows x 6 columns]

# %%
# Display the details of max aged 2musicians from india
df.loc[(df['Profession']=='Musician')&(df['Country']=='india')].sort_values(by='Age',ascending=False).head(2)
# Out:
#          ID  Fname    Lname  Age Profession Country
# 13  4000014   Beth  Woodard   65   Musician   india
# 14  4000015  Julia    Desai   49   Musician   india

# %%
# check for missing values
df.isna()
# Out:
#         ID  Fname  Lname    Age  Profession  Country
# 0    False  False  False  False       False    False
# 1    False  False  False  False       False    False
# 2    False  False  False  False       False    False
# 3    False  False  False  False       False    False
# 4    False  False  False  False       False    False
# ..     ...    ...    ...    ...         ...      ...
# 458  False  False  False  False       False    False
# 459  False  False  False  False       False    False
# 460  False  False  False  False       False    False
# 461  False  False  False  False       False    False
# 462  False  False  False  False       False    False
#
# [463 rows x 6 columns]

# %%
# display fname,prof,age of all teachers in descending order
df.loc[df['Profession']=='Teacher'][['Fname','Profession','Age']].sort_values(by='Age',ascending=False)
# Out:
#        Fname Profession  Age
# 1      Paige    Teacher   74
# 374   Norman    Teacher   63
# 62   Melinda    Teacher   27
# 100    Scott    Teacher   27
# 396     Bill    Teacher   26

# %%
# display fname of max aged person who is a musician from india
df.loc[(df['Profession']=='Musician')&(df['Country']=='india')].sort_values(by='Age').tail(1)[['Fname']]
# Out:
#    Fname
# 13  Beth

# %%
# display the data in indexes 50-60
df.iloc[50:61]
# Out:
#          ID      Fname    Lname  Age         Profession Country
# 50  4000051  Frederick    Baker   52             Writer      uk
# 51  4000052    Shirley  Merritt   21           Reporter      uk
# 52  4000053      Jason    Cross   56     Civil engineer      uk
# 53  4000054     Judith   Cooper   22          Economist      uk
# 54  4000055   Gretchen   Holmes   39   Childcare worker      uk
# 55  4000056        Don   Sharpe   53      Social worker      uk
# 56  4000057     Glenda   Morgan   37  Real estate agent      uk
# 57  4000058      Scott    Hoyle   40             Doctor      uk
# 58  4000059        Pat    Allen   45          Secretary      uk
# 59  4000060   Michelle     Rich   44             Artist      uk
# 60  4000061    Jessica     Rich   37              Actor      uk

# %%
# display fname of min aged dancer from india
df.loc[(df['Profession']=='Dancer')&(df['Country']=='india')].sort_values(by='Age').head(1)[['Fname']]
# Out:
#        Fname
# 23  Franklin

# %%
df3
# Out:
#    Empid Empname Designation  Salary Location
# 0    101     Sam     Manager   10000   Mumbai
# 1    102  Trisha   Developer   13000    Delhi
# 2    103     Anu   Developer   14000      Goa
# 3    104    Manu     Manager   16000  Chennai
# 4    105     Dev   Developer   20000   Kerala
# 5    101     Sam     Manager   10000   Mumbai

# %%
df3.drop_duplicates()   #  removes duplicate from dataframe
# Out:
#    Empid Empname Designation  Salary Location
# 0    101     Sam     Manager   10000   Mumbai
# 1    102  Trisha   Developer   13000    Delhi
# 2    103     Anu   Developer   14000      Goa
# 3    104    Manu     Manager   16000  Chennai
# 4    105     Dev   Developer   20000   Kerala

# %%
# drop column
df3.drop(['Location','Salary'],axis=1)
# Out:
#    Empid Empname Designation
# 0    101     Sam     Manager
# 1    102  Trisha   Developer
# 2    103     Anu   Developer
# 3    104    Manu     Manager
# 4    105     Dev   Developer
# 5    101     Sam     Manager

# %%
# drop row
df3.drop([0,])
# Out:
#    Empid Empname Designation  Salary Location
# 1    102  Trisha   Developer   13000    Delhi
# 2    103     Anu   Developer   14000      Goa
# 3    104    Manu     Manager   16000  Chennai
# 4    105     Dev   Developer   20000   Kerala
# 5    101     Sam     Manager   10000   Mumbai

# %%
# value_counts()  ---> count of specified colomn


# no of cust from each country
df['Country'].value_counts()
# Out:
# Country
# australia    104
# africa        90
# us            78
# ireland       77
# china         56
# uk            37
# india         21
# Name: count, dtype: int64
