# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('/content/drive/MyDrive/Datasets/Real estate.csv')
df
# Out:
# Mounted at /content/drive
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
df.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
df.drop(['No','X1 transaction date'],axis=1,inplace=True)

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,[-1]]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=1)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knn.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 61.34716794569478

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=mlr.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred1)*100
# Out:
# 52.77562430942584

# %% [markdown]
# # **Visualisation**

# %%
import matplotlib.pyplot as plt
x=[2,9,1,6,3]
y=[1,4,2,6,7]
plt.scatter(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %%
plt.plot(x,y)
plt.plot(x,y,'*',c='green')  #change the marker and color
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')
plt.show()

# %%
plt.plot(y,'+:y')  # marker(+),dotted line,color(yellow)
plt.show()

# %%
plt.plot(y,linestyle='dotted',marker='*',color='red',linewidth=1)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o', color='blue', markerfacecolor='red', markeredgecolor='black')
plt.show()

# %%
h=[161,172,158,184,179]
w=[43,55,47,72,85]
plt.plot(h,w)
plt.plot(h,w,marker='o',color='yellow',markerfacecolor='black',markeredgecolor='blue')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height v/s Weight')
plt.grid(color='green',linestyle='--',linewidth=1)
plt.show()

# %% [markdown]
# # creating subplots

# %%
x1=[1,2,3,4]
y1=[4,5,1,3]

plt.subplot(2,1,1)
plt.plot(x1,y1)
plt.title('Graph 1')

x2=[5,6,7,8]
y2=[4,9,2,5]

plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.title('Graph 2')

plt.suptitle('Subplots Example')  # common title for both subgraphs
plt.show()

# %%
x1=[1,2,3,4]
y1=[4,5,1,3]

plt.subplot(1,2,1)
plt.plot(x1,y1)
plt.title('Graph 1')

x2=[5,6,7,8]
y2=[4,9,2,5]

plt.subplot(1,2,2)
plt.plot(x2,y2)
plt.title('Graph 2')

plt.suptitle('Subplots Example')
plt.show()

# %%
x1=[1,2,3,4]
y1=[4,5,1,3]

plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title('Graph 1')

x2=[5,6,7,8]
y2=[4,9,2,5]

plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title('Graph 2')

x3=[4,2,6,8]
y3=[9,5,2,7]

plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title('Graph 3')

x4=[9,4,2,6]
y4=[1,3,5,7]

plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title('Graph 4')

plt.suptitle('Subplots Example')  # common title for both subgraphs
plt.show()

# %%
x=[1,2,3,4]
y=[4,5,1,3]
plt.bar(x,y)  # vertical bars
plt.show()

# %%
x=[1,2,3,4]
y=[4,5,1,3]
plt.barh(x,y,color='green')  # horizontal bars
plt.show()

# %%
x=[1,2,4,5,2,2,2,3,4,2]
plt.hist(x)  #plot  the points according to freq of x   -->HISTOGRAM
plt.show()

# %%
y=[10,20,30,40]
labls=['Apple','Orange','Mango','kiwi']
plt.pie(y,labels=labls)
plt.legend(title='Fruits')
plt.show()
